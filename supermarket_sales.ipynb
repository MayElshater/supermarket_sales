# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
super=pd.read_csv('supermarket_sales - Sheet1.csv')
super.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
super.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
B=super[['Branch','Rating']]
B
# Out:
#     Branch  Rating
# 0        A     9.1
# 1        C     9.6
# 2        A     7.4
# 3        A     8.4
# 4        A     5.3
# ..     ...     ...
# 995      C     6.2
# 996      B     4.4
# 997      A     7.7
# 998      A     4.1
# 999      A     6.6
#
# [1000 rows x 2 columns]

# %%
B.groupby('Branch').value_counts()
# Out:
# Branch  Rating
# A       6.6       11
#         4.2       11
#         7.4        9
#         5.0        8
#         9.8        8
#                   ..
# C       8.9        3
#         5.8        2
#         4.7        2
#         4.6        1
#         10.0       1
# Length: 183, dtype: int64

# %%
from pandas.core import describe
super.groupby('City').describe()
# Out:
#           Unit price                                                         \
#                count       mean        std    min      25%     50%      75%
# City
# Mandalay       332.0  55.659277  26.224559  10.59  33.3000  54.850  77.0025
# Naypyitaw      328.0  56.609024  27.179799  10.16  33.7675  56.810  81.5525
# Yangon         340.0  54.780853  26.132127  10.08  32.2500  53.235  75.0950
#
#                  Quantity            ... gross income        Rating            \
#              max    count      mean  ...          75%    max  count      mean
# City                                 ...
# Mandalay   99.96    332.0  5.481928  ...    22.170750  48.69  332.0  6.818072
# Naypyitaw  99.96    328.0  5.582317  ...    23.607375  49.65  328.0  7.072866
# Yangon     99.83    340.0  5.467647  ...    21.873375  49.49  340.0  7.027059
#
#
#                 std  min  25%  50%  75%   max
# City
# Mandalay   1.713719  4.0  5.3  6.7  8.2  10.0
# ...

# %%
super.groupby('Gender').count()
# Out:
#         Invoice ID  Branch  City  Customer type  Product line  Unit price  \
# Gender
# Female         501     501   501            501           501         501
# Male           499     499   499            499           499         499
#
#         Quantity  Tax 5%  Total  Date  Time  Payment  cogs  \
# Gender
# Female       501     501    501   501   501      501   501
# Male         499     499    499   499   499      499   499
#
#         gross margin percentage  gross income  Rating
# Gender
# Female                      501           501     501
# Male                        499           499     499

# %%
super[super['Gender']=='Female']['Customer type'].value_counts()
# Out:
# Member    261
# Normal    240
# Name: Customer type, dtype: int64

# %%
super[super['Gender']=='Male']['Customer type'].value_counts()
# Out:
# Normal    259
# Member    240
# Name: Customer type, dtype: int64

# %%
A=super[['Gender','Product line']]
A
# Out:
#      Gender            Product line
# 0    Female       Health and beauty
# 1    Female  Electronic accessories
# 2      Male      Home and lifestyle
# 3      Male       Health and beauty
# 4      Male       Sports and travel
# ..      ...                     ...
# 995    Male       Health and beauty
# 996  Female      Home and lifestyle
# 997    Male      Food and beverages
# 998    Male      Home and lifestyle
# 999  Female     Fashion accessories
#
# [1000 rows x 2 columns]

# %%
A.groupby('Gender').value_counts()
# Out:
# Gender  Product line
# Female  Fashion accessories       96
#         Food and beverages        90
#         Sports and travel         88
#         Electronic accessories    84
#         Home and lifestyle        79
#         Health and beauty         64
# Male    Health and beauty         88
#         Electronic accessories    86
#         Food and beverages        84
#         Fashion accessories       82
#         Home and lifestyle        81
#         Sports and travel         78
# dtype: int64

# %%
c=super[['cogs','Product line']]
c.groupby('Product line').describe()
# Out:
#                          cogs                                           \
#                         count        mean         std    min       25%
# Product line
# Electronic accessories  170.0  304.411941  234.233930  25.45  112.8600
# Fashion accessories     178.0  290.561236  231.965838  12.09  101.1000
# Food and beverages      174.0  307.306207  235.388362  21.58  128.4800
# Health and beauty       152.0  308.231447  226.227443  17.75  119.6825
# Home and lifestyle      160.0  320.606625  242.476830  13.98  120.0725
# Sports and travel       166.0  316.252590  236.547931  10.17  126.9150
#
#
#                             50%       75%     max
# Product line
# Electronic accessories  229.730  453.1650  897.57
# Fashion accessories     201.570  421.6100  993.00
# Food and beverages      240.465  431.0925  985.20
# Health and beauty       259.340  469.2575  905.00
# Home and lifestyle      245.895  468.3450  975.00
# Sports and travel       258.030  454.9375  954.40

# %%
from pickle import BINSTRING
Product_line =super['Product line']
cogs  =super['cogs'] 

fig = plt.figure(figsize = (15, 5)) 
plt.bar(Product_line, cogs, color ='maroon', width = 0.4,alpha=.7)
 
plt.xlabel("products line")
plt.ylabel("cogs")
#plt.title("Students enrolled in different courses")
plt.show()

# %%
super[['Product line','Rating','Date']][-10:]
# Out:
#                Product line  Rating       Date
# 990      Food and beverages     4.5  3/22/2019
# 991       Sports and travel     6.0  1/24/2019
# 992  Electronic accessories     8.8  3/10/2019
# 993     Fashion accessories     6.6  2/22/2019
# 994  Electronic accessories     5.9  2/18/2019
# 995       Health and beauty     6.2  1/29/2019
# 996      Home and lifestyle     4.4   3/2/2019
# 997      Food and beverages     7.7   2/9/2019
# 998      Home and lifestyle     4.1  2/22/2019
# 999     Fashion accessories     6.6  2/18/2019

# %%
from pickle import BINSTRING
Product_line =super['Product line']
Rating  =super['Rating'] 

fig = plt.figure(figsize = (15, 5)) 
plt.bar(Product_line, Rating, color ='maroon', width = 0.4,alpha=.7)
 
plt.xlabel("products line")
plt.ylabel("Rating")
#plt.title("Students enrolled in different courses")
plt.show()

# %%
x=super[['cogs','City']]
x.groupby('City').describe()
# Out:
#             cogs                                                              \
#            count        mean         std    min       25%      50%       75%
# City
# Mandalay   332.0  304.640482  230.902443  17.75  114.2250  240.840  443.4150
# Naypyitaw  328.0  321.047348  250.629400  10.17  115.6900  258.495  472.1475
# Yangon     340.0  297.480029  220.609547  12.09  130.9425  229.360  437.4675
#
#
#              max
# City
# Mandalay   973.8
# Naypyitaw  993.0
# Yangon     989.8
